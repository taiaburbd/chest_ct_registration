# %% [markdown]
# # MIRA: Final Project 2023
# Professor: Josep Quintana, Robert Martí
#
# Topic: Image registration of chest CT volumes: 4DCT DIR-Lab Challenge
#
# Taiabur

# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
import nibabel as nib
from typing import Tuple
from pathlib import Path
from utils.registration import elastix_transformix_registration_method
# Out:
# /var/folders/zp/kn2c7zks0q55p6_3s3c4b97h0000gn/T/ipykernel_9555/2466426861.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# image registration

# %%
# Path Setup
MAIN_PATH       = Path('./').resolve()
TRAIN_DATA_PATH = MAIN_PATH / 'dataset' / 'train'
OUTPUT_DATA_PATH = MAIN_PATH / 'dataset' / 'output'
PARAMETER_PATH = MAIN_PATH / 'parameter'

# %%
param_name = 'rigid'
parameter =[
    "Par0056rigid.txt",
]

elastix_transformix_registration_method(parameter,PARAMETER_PATH, TRAIN_DATA_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: rigid
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_eBHCT.nii.gz
# ...

# %%
param_name = 'affine'
parameter =[
    "Parameters.Par0011.affine.txt"
]

elastix_transformix_registration_method(parameter,PARAMETER_PATH, TRAIN_DATA_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: affine
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_eBHCT.nii.gz
# ...

# %%
param_name = 'bspline1'
parameter =[
    "Parameters.Par0011.bspline1_s.txt"
]

elastix_transformix_registration_method(parameter,PARAMETER_PATH, TRAIN_DATA_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: bspline1
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_eBHCT.nii.gz
# ...

# %%
param_name = 'bspline2'
parameter =[
    "Parameters.Par0011.bspline2_s.txt",
]

elastix_transformix_registration_method(parameter,PARAMETER_PATH, TRAIN_DATA_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: bspline2
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_eBHCT.nii.gz
# ...

# %%
param_name = 'affine_bspline1_s'
parameter =[
    "Parameters.Par0011.affine.txt",
    "Parameters.Par0011.bspline1_s.txt",
    # "Parameters.Par0011.bspline2_s.txt",
]


elastix_transformix_registration_method(parameter,PARAMETER_PATH, TRAIN_DATA_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: affine_bspline1_s
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_eBHCT.nii.gz
# ...

# %%
param_name = 'affine_bspline1_bspline2'
parameter =[
    "Parameters.Par0011.affine.txt",
    "Parameters.Par0011.bspline1_s.txt",
    "Parameters.Par0011.bspline2_s.txt",
]

elastix_transformix_registration_method(parameter,PARAMETER_PATH, TRAIN_DATA_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: affine_bspline1_bspline2
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/git/chest_ct_registration/dataset/train/copd3/copd3_eBHCT.nii.gz
# ...
