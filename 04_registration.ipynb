# %% [markdown]
# # MIRA: Final Project 2023
# Professor: Josep Quintana, Robert Martí
#
# Topic: Image registration of chest CT volumes: 4DCT DIR-Lab Challenge
#
# Taiabur

# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  
import nibabel as nib
from typing import Tuple
from pathlib import Path
from utils.registration import elastix_transformix_registration_method

# %% [markdown]
# image registration

# %%
PARAM_PATH = Path('/Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/parameter/')
IMAGE_PATH = Path('/Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/')
OUTPUT_DATA_PATH = Path('//Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/output/')

# %%
param_name = 'rigid'
parameter =[
    "Par0056rigid.txt",
]

elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: rigid
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...

# %%
param_name = 'affine-manasi'
parameter =[
    "Parameter.affine.txt"
]

elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: affine-manasi
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...

# %%
param_name = 'bsplines-manasi'
parameter =[
    "Parameter.bsplines.txt"
]

elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: bsplines-manasi
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...

# %%
param_name = 'affine'
parameter =[
    "Parameters.Par0011.affine.txt"
]

elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: affine
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...

# %%
param_name = 'bspline1'
parameter =[
    "Parameters.Par0011.bspline1_s.txt"
]

elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: bspline1
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...

# %%
param_name = 'bspline2'
parameter =[
    "Parameters.Par0011.bspline2_s.txt",
]

elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: bspline2
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...

# %%
param_name = 'affine_bspline1_s'
parameter =[
    "Parameters.Par0011.affine.txt",
    "Parameters.Par0011.bspline1_s.txt",
    # "Parameters.Par0011.bspline2_s.txt",
]


elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: affine_bspline1_s
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...

# %%
param_name = 'affine_bspline1_bspline2'
parameter =[
    "Parameters.Par0011.affine.txt",
    "Parameters.Par0011.bspline1_s.txt",
    "Parameters.Par0011.bspline2_s.txt",
]

elastix_transformix_registration_method(parameter,PARAM_PATH, IMAGE_PATH, OUTPUT_DATA_PATH, param_name)
# Out:
# Starting Registration -> Parameter: affine_bspline1_bspline2
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd1/copd1_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_iBHCT.nii.gz
# Moving Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_eBHCT.nii.gz
# Inhale landmark Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd2/copd2_300_iBH_xyz_r1.txt
# Fixed Image Path /Users/taiaburrahman/Desktop/Udg/MIRA/chest_ct_registration/dataset/train/copd3/copd3_iBHCT.nii.gz
# ...
